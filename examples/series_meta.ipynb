# %%
import kooplearn
import kooplearn.datasets
import matplotlib.pyplot as plt

# %%
import logging
import math
from pathlib import Path
from typing import Optional

import numpy as np
import scipy
import scipy.sparse
from scipy.integrate import romb
from scipy.special import binom
from scipy.stats.sampling import NumericalInversePolynomial

from kooplearn._src.utils import topk
from kooplearn.datasets.misc import (
    DataGenerator,
    DiscreteTimeDynamics,
    LinalgDecomposition,
)
import tqdm

from kooplearn.datasets.stochastic import LangevinTripleWell1D
class LangevinTripleWell1D(DiscreteTimeDynamics):
    def __init__(
        self,
        gamma: float = 0.1,
        kt: float = 1.0,
        dt: float = 1e-4,
        rng_seed: Optional[int] = None,
        height=0.1,
        sigma=0.05,
        freq=500
    ):
        self.gamma = gamma
        self.kt = kt
        self.rng = np.random.default_rng(rng_seed)
        self.dt = dt

        self._inv_gamma = (self.gamma) ** -1
        self.list_centers = []
        self.height = height
        self.sigma = sigma
        self.freq = freq
    def sample(self, X0: np.ndarray, T: int = 1, show_progress: bool = False):
        X0 = np.asarray(X0)
        if X0.ndim == 0:
            X0 = X0[None]

        memory = np.zeros((T + 1,) + X0.shape)
        meta_forces = np.zeros((T + 1,) + X0.shape)
        forces = np.zeros((T + 1,) + X0.shape)
        memory[0] = X0
        show_progress = True
        if show_progress:
            _iter = tqdm.tqdm(range(T), desc="Generating data", unit="step", leave=False)
        else:
            _iter = range(T)

        for t in _iter:
            if t% self.freq ==0 and t !=0:
                self.list_centers.append(memory[t])
            memory[t + 1], forces[t+1], meta_forces[t + 1] = self._step(memory[t])
        return memory, forces, meta_forces
    def eig(self):
        if not hasattr(self, "_ref_evd"):
            self._compute_ref_evd()
        return self._ref_evd
    def _compute_ref_evd(self):
        assets_path = Path(__file__).parent / "assets"

        lap_x = scipy.sparse.load_npz(assets_path / "1D_triple_well_lap_x.npz")
        grad_x = scipy.sparse.load_npz(assets_path / "1D_triple_well_grad_x.npz")
        cc = np.load(assets_path / "1D_triple_well_cc.npz")

        force = scipy.sparse.diags(self.force_fn(cc))

        # Eq.(31) of https://doi.org/10.1007/978-3-642-56589-2_9 recalling that \sigma^2/(\gamma*2) = kBT
        generator = self._inv_gamma * self.kt * lap_x + self._inv_gamma * force.dot(
            grad_x
        )
        generator = generator * self.dt

        vals, vecs = np.linalg.eig(generator.toarray())

        # Filter out timescales smaller than dt
        mask = np.abs(vals.real) < 1.0
        vals = vals[mask]
        vecs = vecs[:, mask]

        vals = np.exp(vals)
        # Checking that the eigenvalues are real
        type_ = vals.dtype.type
        f = np.finfo(type_).eps

        tol = f * 1000
        if not np.all(np.abs(vals.imag) < tol):
            raise ValueError(
                "The computed eigenvalues are not real, try to decrease dt"
            )
        else:
            vals = vals.real

        _k = len(vals)
        evd_sorting_perm = topk(vals, _k)
        vals = evd_sorting_perm.values
        vecs = vecs[:, evd_sorting_perm.indices].real

        dx = cc[1] - cc[0]
        boltzmann_pdf = (dx**-1) * scipy.special.softmax(self.force_fn(cc) / self.kt)
        abs2_eigfun = (np.abs(vecs) ** 2).T
        eigfuns_norms = np.sqrt(romb(boltzmann_pdf * abs2_eigfun, dx=dx, axis=-1))
        vecs = vecs * (eigfuns_norms**-1.0)

        # Storing the results
        self._ref_evd = LinalgDecomposition(vals, cc, vecs)
        self._ref_boltzmann_density = boltzmann_pdf

    def _step(self, X: np.ndarray):
        F, bias = self.force_fn(X)
        xi = self.rng.standard_normal(X.shape)
        dX = (
            F * self._inv_gamma * self.dt
            + np.sqrt(2.0 * self.kt * self.dt * self._inv_gamma) * xi
        )
        return X + dX, F, bias
    def meta_force(self,x):
        return  ((x - np.array(self.list_centers)) * self.height * np.exp( - ( x - np.array(self.list_centers))**2 / (2 * self.sigma **2))).sum() / (self.sigma**2)
    def force_fn(self, x: np.ndarray):
        bias = self.meta_force(x)
        return -4.0 * (
            -32 * np.exp(-80 * ((-0.5 + x) ** 2)) * (-0.5 + x)
            - 512 * np.exp(-80 * (x**2)) * x
            + 8* (x**7)
            - 40 * np.exp(-40 * ((0.5 + x) ** 2)) * (0.5 + x)
        )+ bias, bias  #-8*(x-1)*(x+1)**2 - 8*(x-1)**2*(x+1)

# %%
from sklearn.gaussian_process.kernels import RBF
from kooplearn.data import traj_to_contexts
models = []
samples = []
forces_all =[]
biases = []
for i in range(30):
    langevin = LangevinTripleWell1D(gamma=0.1,dt=1e-4,height=0.05,sigma=0.1,freq=1000) #sigma=0.1    
    sample,forces, meta_forces = langevin.sample(0, 500_000)
    samples.append(sample)
    forces_all.append(forces)
    biases.append(meta_forces)

# %%
import matplotlib.pyplot as plt
plt.hist(sample, bins=500, density=True);

# %%
plt.plot(sample)

# %%
print(np.where(samples[0]<0))
# Out:
# (array([190010, 190011, 190012, ..., 337370, 337371, 337372]), array([0, 0, 0, ..., 0, 0, 0]))

# %%
values = np.zeros((10,6))
vecs_gen1 = np.zeros((10,4999,6))

def find_sign_changes_indices(sequence):
    return [i for i in range(1, len(sequence)) if sequence[i-1] * sequence[i] < 0]

models = []
all_training_set = []
all_training_forces = []
all_bias_forces = []
for i in range(30):
    kernel = RBF(length_scale=0.3) #0.65 works  well #0.4 best
    model = kooplearn.models.KernelDMD(kernel, reduced_rank=True, rank=6
                                   
                                   , tikhonov_reg=1e-2
                                   , fit_generator=True,mean_features=False)
    indices = find_sign_changes_indices(samples[i])
    if indices[0] < 1000:
        if indices[1]<1000:
            index = indices[2]+20000
        else:
            index = indices[1]+20000
    else:
        index = indices[0]+20000
 
    test=samples[i][:index:200]
    train_data = traj_to_contexts(test)
    forces_train = traj_to_contexts(forces_all[i][:index:200])
    train_data.shape
    bias = traj_to_contexts(biases[i][:index:200])
    model = model.fit(train_data,forces=(forces_train-bias)/0.1,friction=2/0.1) #np.sqrt(2))
    models.append(model)
    all_training_set.append(samples[i][:index])
    all_training_forces.append(forces_all[i][:index])
    all_bias_forces.append(biases[i][:index])
    #vals,values[i],vecs,vecs_gen1[i] = model.eig(eval_right_on=common_ground)
# Out:
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1
# hello
# 0.3
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1

# %%
models
# Out:
# [<kooplearn.models.kernel.KernelDMD at 0x7f3faafced70>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3faafcf250>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fcfaa7040>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab3c0820>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3faafcf0d0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab098400>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab09a4a0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab09abf0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab0985e0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab099a20>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab09bf70>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab099240>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab098eb0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab099720>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab098ac0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab09a320>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab09bf10>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab2ee410>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab428df0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab42af80>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab4294b0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab428d30>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab429810>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab42a020>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab42b670>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab42a230>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab42a320>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab42b0d0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab42a7d0>,
#  <kooplearn.models.kernel.KernelDMD at 0x7f3fab428f70>]

# %%
common_ground = train_data[:,:1, ...]
values = np.zeros((30,6))
vecs_gen1 = np.zeros((30,common_ground.shape[0],6))
for i in range(30):

    vals,values[i],vecs,vecs_gen1[i] = models[i].eig(eval_right_on=common_ground)
# Out:
# /tmp/ipykernel_2657159/1873534508.py:6: ComplexWarning: Casting complex values to real discards the imaginary part
#   vals,values[i],vecs,vecs_gen1[i] = models[i].eig(eval_right_on=common_ground)

# %%
values.mean(axis=0)
# Out:
# array([-9.14658138e+02, -7.30581221e+02, -3.18780012e+02, -1.42143439e+02,
#        -6.18401498e+01, -6.04143704e-01])

# %%
vecs_gen = vecs_gen1.mean(axis=0)

# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt




solutions =np.load("/home/tdevergne@iit.local/Documents/eigenfunctions.np",allow_pickle=True)
x_values  =np.load("/home/tdevergne@iit.local/Documents/centers.np",allow_pickle=True)
plt.scatter(common_ground,vecs_gen[:,-4],label="PCR generator first eigenfunction")
#plt.scatter(np.squeeze(train_data[:,:1, ...]), vecs[:,-2],label="PCR transfer first eigenfunction")
#plt.plot(decomp.x[values],-funcs[values,2],label="exact eigenfunction",color="r")

plt.plot()
num = 3
fig, axes = plt.subplots(num, num, figsize=(20, 20))
#values = np.where(np.logical_and(decomp.x>-1,decomp.x<1))[0]
print(np.where(vecs_gen[:,-1]==0))

new_0 = -(vecs_gen[:,-1]-vecs_gen[:,-1].min())/(vecs_gen[:,-1].min()-vecs_gen[:,-1].max())

for i in range(5):
    #vecs_gen[:,-i-1] /= vecs_gen[:,-1]
    #vecs_gen[:,-i-1] /= vecs_gen[:,-1]
    new = (vecs_gen[:,-i-1]-vecs_gen[:,-i-1].min())/(vecs_gen[:,-i-1].min()-vecs_gen[:,-i-1].max())
    new_sol = (solutions[:,i+1]-solutions[:,i+1].min())/(solutions[:,i+1].min()-solutions[:,i+1].max())
    if i ==2 or i==0 or i==1:
        axes[i//num, i%num].scatter(np.squeeze(train_data[:,:1, ...]), -new-1, marker="+", color='C0',label="generator RRR EF")
    else:
        axes[i//num, i%num].scatter(np.squeeze(train_data[:,:1, ...]), new, marker="+", color='C0',label="generator RRR EF")
    axes[i//num, i%num].scatter(x_values,new_sol, marker="+", color='k', label="generator exact EF")

    axes[i//num, i%num].grid(True, linestyle='--', alpha=.5)
    axes[i//num, i%num].set_xlim(-1, 1)
    #axes[i//num, i%num].set_ylim(y_min, y_max)

    axes[i//num, i%num].legend()

plt.xlabel('x')
#plt.ylabel('')
plt.legend()
plt.show()
# Out:
# /home/tdevergne@iit.local/anaconda3/envs/kooplearn-dev/lib/python3.10/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/tdevergne@iit.local/anaconda3/envs/kooplearn-dev/lib/python3.10/site-packages/matplotlib/collections.py:194: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (array([], dtype=int64),)

# %%
train_data = np.concatenate([traj_to_contexts(all_training_set[i][::1000]) for i in range(30)])
forces_train = np.concatenate([traj_to_contexts(all_training_forces[i][::1000]) for i in range(30)])

bias = np.concatenate([traj_to_contexts(all_bias_forces[i][::1000]) for i in range(30)])
kernel = RBF(length_scale=0.4) #0.65 works  well #0.4 best
model = kooplearn.models.KernelDMD(kernel, reduced_rank=True, rank=6
                               
                               , tikhonov_reg=2e-2
                               , fit_generator=True,mean_features=False)

# %%
len(all_training_set[0])
# Out:
# 210010

# %%
train_data.shape
# Out:
# (7331, 2, 1)

# %%
forces_train.shape
# Out:
# (7331, 2, 1)

# %%
bias.shape
# Out:
# (7331, 2, 1)

# %%
   
model = model.fit(train_data,forces=(forces_train-bias)/0.1,friction=2/0.1) #np.sqrt(2))
# Out:
# hello
# 0.4
# [[0.]]
# Fitting transfer operator
# Fitting generator
# Fitted KernelDMD model. Lookback length set to 1

# %%
vals,vals_gen,vecs,vecs_gen = model.eig(eval_right_on=train_data[:,:1, ...])

# %%
vals_gen
# Out:
# array([-445.84850923+0.j        , -304.5776478 +0.j        ,
#        -190.93030414+0.j        ,  -79.19806731+0.j        ,
#          -0.60915694-2.04189182j,   -0.60915694+2.04189182j])

# %% [markdown]
# ######

# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt




solutions =np.load("/home/tdevergne@iit.local/Documents/eigenfunctions.np",allow_pickle=True)
x_values  =np.load("/home/tdevergne@iit.local/Documents/centers.np",allow_pickle=True)
plt.scatter(np.squeeze(train_data[:,:1, ...]),vecs_gen[:,-4],label="PCR generator first eigenfunction")
#plt.scatter(np.squeeze(train_data[:,:1, ...]), vecs[:,-2],label="PCR transfer first eigenfunction")
#plt.plot(decomp.x[values],-funcs[values,2],label="exact eigenfunction",color="r")

plt.plot()
num = 3
fig, axes = plt.subplots(num, num, figsize=(20, 20))
#values = np.where(np.logical_and(decomp.x>-1,decomp.x<1))[0]
print(np.where(vecs_gen[:,-1]==0))

new_0 = -(vecs_gen[:,-1]-vecs_gen[:,-1].min())/(vecs_gen[:,-1].min()-vecs_gen[:,-1].max())

for i in range(4):
    #vecs_gen[:,-i-1] /= vecs_gen[:,-1]
    #vecs_gen[:,-i-1] /= vecs_gen[:,-1]
    new = (vecs_gen[:,-i-1]-vecs_gen[:,-i-1].min())/(vecs_gen[:,-i-1].min()-vecs_gen[:,-i-1].max())
    new_sol = (solutions[:,i+1]-solutions[:,i+1].min())/(solutions[:,i+1].min()-solutions[:,i+1].max())
    if i ==4 or i ==5:
        axes[i//num, i%num].scatter(np.squeeze(train_data[:,:1, ...]), -new-1, marker="+", color='C0',label="generator RRR EF")
    else:
        axes[i//num, i%num].scatter(np.squeeze(train_data[:,:1, ...]), new, marker="+", color='C0',label="generator RRR EF")
    axes[i//num, i%num].scatter(x_values,new_sol, marker="+", color='k', label="generator exact EF")

    axes[i//num, i%num].grid(True, linestyle='--', alpha=.5)
    axes[i//num, i%num].set_xlim(-1, 1)
    #axes[i//num, i%num].set_ylim(y_min, y_max)

    axes[i//num, i%num].legend()

plt.xlabel('x')
#plt.ylabel('')
plt.legend()
plt.show()
# Out:
# /home/tdevergne@iit.local/anaconda3/envs/kooplearn-dev/lib/python3.10/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/tdevergne@iit.local/anaconda3/envs/kooplearn-dev/lib/python3.10/site-packages/matplotlib/collections.py:194: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (array([], dtype=int64),)

# %%
plt.plot(decomp.x,funcs[:,1],label="exact eigenfunction",color="r")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/tdevergne@iit.local/Documents/kooplearn/examples/series_meta.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/home/tdevergne%40iit.local/Documents/kooplearn/examples/series_meta.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(decomp.x,funcs[:,1],label="exact eigenfunction",color="r")
#
# NameError: name 'decomp' is not defined

# %%
np.real(vecs_gen[:,-i-1]/vecs_gen[:,-1])
# Out:
# array([-0.08255885, -0.06062868,  0.09228294, ..., -0.01325368,
#         0.05357351,  0.07160568])
